# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('mental_health_prediction.csv')

# %%
df.sample(5)
# Out:
#      age      gender                     occupation  sleep_hours  \
# 420   35      Female  Both (Part-time work + Study)          6.2
# 272   27  Non-binary  Both (Part-time work + Study)          6.7
# 219   25  Non-binary           Working Professional          3.0
# 227   26      Female  Both (Part-time work + Study)          4.8
# 304   29      Female           Working Professional         10.6
#
#      sleep_quality  social_media_hours  academic_work_pressure  \
# 420            4.0                 6.8                     8.0
# 272            4.0                 6.3                     5.0
# 219            3.0                 4.1                     9.0
# 227            NaN                 3.3                     7.0
# 304            8.0                 3.1                     5.0
#
#      physical_activity_days  stress_level  anxiety_score  depression_score  \
# 420                     0.0           7.0            2.0               4.0
# 272                     3.0           7.0            7.0               3.0
# 219                     2.0           8.0            6.0               5.0
# 227                     1.0           6.0            6.0               2.0
# 304                     4.0           2.0            3.0               1.0
#
#      work_life_balance  mood_score  concentration_level  social_support  \
# 420                4.0         NaN                  5.0             1.0
# 272                2.0         5.0                  3.0             5.0
# 219                2.0         3.0                  2.0             1.0
# 227                3.0         5.0                  5.0             3.0
# 304                7.0         7.0                  8.0            10.0
#
#     mental_health_condition  severity  \
# 420              Depression      Mild
# 272                 Anxiety      Mild
# 219                 Burnout  Moderate
# 227                 Anxiety      Mild
# 304                  Normal      Mild
#
#                                              treatment
# 420  Psychotherapy, antidepressants (SSRIs), regula...
# 272  Cognitive Behavioral Therapy (CBT), mindfulnes...
# 219  Rest, work-life balance improvement, therapy, ...
# 227  Cognitive Behavioral Therapy (CBT), mindfulnes...
# 304  No treatment needed; maintain healthy lifestyl...

# %%
df.shape
# Out:
# (500, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      500 non-null    int64
#  1   gender                   500 non-null    object
#  2   occupation               500 non-null    object
#  3   sleep_hours              485 non-null    float64
#  4   sleep_quality            479 non-null    float64
#  5   social_media_hours       481 non-null    float64
#  6   academic_work_pressure   467 non-null    float64
#  7   physical_activity_days   480 non-null    float64
#  8   stress_level             472 non-null    float64
#  9   anxiety_score            478 non-null    float64
#  10  depression_score         478 non-null    float64
#  11  work_life_balance        482 non-null    float64
#  12  mood_score               480 non-null    float64
#  13  concentration_level      479 non-null    float64
#  14  social_support           470 non-null    float64
#  15  mental_health_condition  500 non-null    object
#  16  severity                 500 non-null    object
#  17  treatment                500 non-null    object
# dtypes: float64(12), int64(1), object(5)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#               age  sleep_hours  sleep_quality  social_media_hours  \
# count  500.000000   485.000000     479.000000          481.000000
# mean    26.832000     6.769691       4.822547            4.235343
# std      7.735597     1.939245       2.099968            2.002300
# min     15.000000     3.000000       1.000000            0.000000
# 25%     21.000000     5.300000       3.000000            2.600000
# 50%     26.000000     6.700000       5.000000            4.300000
# 75%     32.000000     8.100000       6.000000            5.800000
# max     52.000000    12.000000      10.000000            9.300000
#
#        academic_work_pressure  physical_activity_days  stress_level  \
# count              467.000000              480.000000    472.000000
# mean                 6.100642                1.606250      5.993644
# std                  2.229470                1.589751      2.549294
# min                  1.000000                0.000000      1.000000
# 25%                  4.000000                0.000000      4.000000
# 50%                  6.000000                1.000000      6.000000
# 75%                  8.000000                3.000000      8.000000
# max                 10.000000                7.000000     10.000000
#
#        anxiety_score  depression_score  work_life_balance  mood_score  \
# count     478.000000        478.000000         482.000000  480.000000
# mean        4.763598          4.953975           3.784232    4.377083
# std         2.338398          2.437043           2.523717    2.354203
# min         1.000000          1.000000           1.000000    1.000000
# 25%         3.000000          3.000000           2.000000    2.000000
# 50%         5.000000          5.000000           3.000000    4.000000
# 75%         7.000000          7.000000           6.000000    6.000000
# max        10.000000         10.000000          10.000000   10.000000
#
#        concentration_level  social_support
# count           479.000000      470.000000
# mean              4.496868        4.489362
# std               2.370383        2.369604
# min               1.000000        1.000000
# 25%               3.000000        3.000000
# 50%               4.000000        4.000000
# 75%               6.000000        7.000000
# max              10.000000       10.000000

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# occupation                  0
# sleep_hours                15
# sleep_quality              21
# social_media_hours         19
# academic_work_pressure     33
# physical_activity_days     20
# stress_level               28
# anxiety_score              22
# depression_score           22
# work_life_balance          18
# mood_score                 20
# concentration_level        21
# social_support             30
# mental_health_condition     0
# severity                    0
# treatment                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 1. Fill numeric columns first
df.fillna(df.median(numeric_only=True), inplace=True)

# 2. Fill any remaining text columns with a placeholder
df.fillna("Unknown", inplace=True)

# %%
df.sample(5)
# Out:
#      age      gender                     occupation  sleep_hours  \
# 467   39  Non-binary                        Student          7.9
# 161   23      Female  Both (Part-time work + Study)          8.7
# 213   25        Male           Working Professional          8.7
# 21    15        Male                        Student          3.0
# 251   26  Non-binary  Both (Part-time work + Study)          5.2
#
#      sleep_quality  social_media_hours  academic_work_pressure  \
# 467            5.0                 2.7                     2.0
# 161            2.0                 4.3                     4.0
# 213            5.0                 4.4                     8.0
# 21             4.0                 5.8                     8.0
# 251            3.0                 2.5                     8.0
#
#      physical_activity_days  stress_level  anxiety_score  depression_score  \
# 467                     5.0           6.0            1.0               3.0
# 161                     0.0           7.0            5.0               9.0
# 213                     0.0           6.0            5.0               8.0
# 21                      1.0           6.0            8.0               2.0
# 251                     0.0          10.0            4.0               6.0
#
#      work_life_balance  mood_score  concentration_level  social_support  \
# 467                8.0         8.0                  9.0             7.0
# 161                2.0         3.0                  4.0             3.0
# 213                2.0         2.0                  4.0             2.0
# 21                 3.0         5.0                  5.0             4.0
# 251                1.0         3.0                  2.0             3.0
#
#     mental_health_condition  severity  \
# 467                  Normal      Mild
# 161              Depression  Moderate
# 213              Depression  Moderate
# 21                  Anxiety  Moderate
# 251                 Burnout  Moderate
#
#                                              treatment
# 467  No treatment needed; maintain healthy lifestyl...
# 161  Psychotherapy, antidepressants (SSRIs), regula...
# 213  Psychotherapy, antidepressants (SSRIs), regula...
# 21   Cognitive Behavioral Therapy (CBT), mindfulnes...
# 251  Rest, work-life balance improvement, therapy, ...

# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-3.22.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.4.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting beautifulsoup4!=4.13.0b2 (from dtale)
#   Downloading beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (2026.5.20)
# Requirement already satisfied: cycler in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (0.12.1)
# Collecting dash (from dtale)
#   Downloading dash-4.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting dash-bootstrap-components (from dtale)
#   Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Collecting et_xmlfile (from dtale)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting Flask (from dtale)
#   Downloading flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Flask-Compress (from dtale)
#   Downloading flask_compress-1.24-py3-none-any.whl.metadata (11 kB)
# Collecting future>=0.14.0 (from dtale)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: itsdangerous in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (2.2.0)
# Collecting kaleido (from dtale)
#   Downloading kaleido-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (3.11.0)
# Collecting missingno (from dtale)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting networkx (from dtale)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (2.4.6)
# Collecting openpyxl!=3.2.0b1 (from dtale)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (26.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (2.3.3)
# Collecting pkginfo (from dtale)
#   Downloading pkginfo-1.12.1.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: plotly in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (6.8.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (2.34.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (1.9.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (1.17.1)
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (0.13.2)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Collecting statsmodels (from dtale)
#   Downloading statsmodels-0.14.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dtale) (1.17.0)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting xarray (from dtale)
#   Downloading xarray-2026.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting xlrd (from dtale)
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4!=4.13.0b2->dtale)
#   Downloading soupsieve-2.8.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (4.15.0)
# Collecting importlib-metadata (from dash->dtale)
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting retrying (from dash->dtale)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from dash->dtale) (82.0.1)
# Collecting janus>=1.0.0 (from dash->dtale)
#   Downloading janus-2.0.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pydantic>=2.10 (from dash->dtale)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting mcp>=1.23.0 (from dash->dtale)
#   Downloading mcp-1.28.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: blinker>=1.9.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from Flask->dtale) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from Flask->dtale) (8.4.1)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from Flask->dtale) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from Flask->dtale) (3.0.3)
# Requirement already satisfied: anyio>=4.5 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from mcp>=1.23.0->dash->dtale) (4.13.0)
# Collecting httpx-sse>=0.4 (from mcp>=1.23.0->dash->dtale)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting httpx<1.0.0,>=0.27.1 (from mcp>=1.23.0->dash->dtale)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from mcp>=1.23.0->dash->dtale) (4.26.0)
# Collecting pydantic-settings>=2.5.2 (from mcp>=1.23.0->dash->dtale)
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash->dtale)
#   Downloading pyjwt-2.13.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from mcp>=1.23.0->dash->dtale) (0.0.32)
# Collecting sse-starlette>=1.6.1 (from mcp>=1.23.0->dash->dtale)
#   Downloading sse_starlette-3.4.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: starlette>=0.27 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from mcp>=1.23.0->dash->dtale) (1.3.1)
# Collecting typing-inspection>=0.4.1 (from mcp>=1.23.0->dash->dtale)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from mcp>=1.23.0->dash->dtale) (0.49.0)
# Collecting httpcore==1.* (from httpx<1.0.0,>=0.27.1->mcp>=1.23.0->dash->dtale)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from httpx<1.0.0,>=0.27.1->mcp>=1.23.0->dash->dtale) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp>=1.23.0->dash->dtale) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.10->dash->dtale)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic>=2.10->dash->dtale)
#   Downloading pydantic_core-2.46.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23.0->dash->dtale) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23.0->dash->dtale) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23.0->dash->dtale) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23.0->dash->dtale) (2026.5.1)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from plotly->dtale) (2.22.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings>=2.5.2->mcp>=1.23.0->dash->dtale)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash->dtale)
#   Downloading cryptography-49.0.0-cp311-abi3-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash->dtale)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash->dtale)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting brotli (from Flask-Compress->dtale)
#   Downloading brotli-1.2.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (6.1 kB)
# Collecting backports.zstd (from Flask-Compress->dtale)
#   Downloading backports_zstd-1.6.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata->dash->dtale)
#   Downloading zipp-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting choreographer>=1.3.0 (from kaleido->dtale)
#   Downloading choreographer-1.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting logistro>=1.0.8 (from kaleido->dtale)
#   Downloading logistro-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting orjson>=3.10.15 (from kaleido->dtale)
#   Downloading orjson-3.11.9-cp313-cp313-macosx_15_0_arm64.whl.metadata (41 kB)
# Requirement already satisfied: platformdirs>=4.3.6 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from choreographer>=1.3.0->kaleido->dtale) (4.9.4)
# Collecting simplejson>=3.19.3 (from choreographer>=1.3.0->kaleido->dtale)
#   Downloading simplejson-4.1.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib->dtale) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib->dtale) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib->dtale) (1.5.0)
# Requirement already satisfied: pillow>=9 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib->dtale) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib->dtale) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from pandas->dtale) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from pandas->dtale) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from requests->dtale) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from requests->dtale) (2.7.0)
# Requirement already satisfied: joblib>=1.4.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from scikit-learn->dtale) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from scikit-learn->dtale) (3.6.0)
# Collecting patsy>=0.5.6 (from statsmodels->dtale)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Downloading dtale-3.22.0-py2.py3-none-any.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 1.3 MB/s  0:00:13m0:00:0100:01m
# Downloading beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading soupsieve-2.8.4-py3-none-any.whl (37 kB)
# Downloading dash-4.3.0-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 1.9 MB/s  0:00:04 eta 0:00:01
# Downloading flask-3.1.3-py3-none-any.whl (103 kB)
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Downloading janus-2.0.0-py3-none-any.whl (12 kB)
# Downloading mcp-1.28.0-py3-none-any.whl (221 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp313-cp313-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.4 MB/s  0:00:01 eta 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
# Downloading pyjwt-2.13.0-py3-none-any.whl (31 kB)
# Downloading cryptography-49.0.0-cp311-abi3-macosx_11_0_arm64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 1.9 MB/s  0:00:02 eta 0:00:01
# Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading sse_starlette-3.4.4-py3-none-any.whl (16 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading flask_compress-1.24-py3-none-any.whl (11 kB)
# Downloading backports_zstd-1.6.0-cp313-cp313-macosx_11_0_arm64.whl (363 kB)
# Downloading brotli-1.2.0-cp313-cp313-macosx_10_13_universal2.whl (861 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.5/861.5 kB 1.7 MB/s  0:00:00 eta 0:00:01
# Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Downloading zipp-4.1.0-py3-none-any.whl (10 kB)
# Downloading kaleido-1.3.0-py3-none-any.whl (55 kB)
# Downloading choreographer-1.3.0-py3-none-any.whl (52 kB)
# Downloading logistro-2.0.1-py3-none-any.whl (8.6 kB)
# Downloading orjson-3.11.9-cp313-cp313-macosx_15_0_arm64.whl (128 kB)
# Downloading simplejson-4.1.1-cp313-cp313-macosx_11_0_arm64.whl (91 kB)
# Downloading lz4-4.4.5-cp313-cp313-macosx_11_0_arm64.whl (207 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.9 MB/s  0:00:01 eta 0:00:01
# Downloading pkginfo-1.12.1.2-py3-none-any.whl (32 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading statsmodels-0.14.6-cp313-cp313-macosx_11_0_arm64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 2.1 MB/s  0:00:04eta 0:00:01
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Downloading xarray-2026.4.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.3 MB/s  0:00:00 eta 0:00:01
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: strsimpy, squarify, brotli, zipp, xlrd, werkzeug, typing-inspection, soupsieve, simplejson, retrying, python-dotenv, pyjwt, pydantic-core, pycparser, pkginfo, patsy, orjson, networkx, lz4, logistro, janus, httpx-sse, httpcore, future, et_xmlfile, backports.zstd, annotated-types, pydantic, openpyxl, importlib-metadata, httpx, Flask, choreographer, cffi, beautifulsoup4, xarray, statsmodels, sse-starlette, pydantic-settings, kaleido, Flask-Compress, cryptography, missingno, mcp, dash, dash-bootstrap-components, dtale
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47/47 [dtale]m [dtale]m [dash]ography]4]
# Successfully installed Flask-3.1.3 Flask-Compress-1.24 annotated-types-0.7.0 backports.zstd-1.6.0 beautifulsoup4-4.15.0 brotli-1.2.0 cffi-2.0.0 choreographer-1.3.0 cryptography-49.0.0 dash-4.3.0 dash-bootstrap-components-2.0.4 dtale-3.22.0 et_xmlfile-2.0.0 future-1.0.0 httpcore-1.0.9 httpx-0.28.1 httpx-sse-0.4.3 importlib-metadata-9.0.0 janus-2.0.0 kaleido-1.3.0 logistro-2.0.1 lz4-4.4.5 mcp-1.28.0 missingno-0.5.2 networkx-3.6.1 openpyxl-3.1.5 orjson-3.11.9 patsy-1.0.2 pkginfo-1.12.1.2 pycparser-3.0 pydantic-2.13.4 pydantic-core-2.46.4 pydantic-settings-2.14.2 pyjwt-2.13.0 python-dotenv-1.2.2 retrying-1.4.2 simplejson-4.1.1 soupsieve-2.8.4 squarify-0.4.4 sse-starlette-3.4.4 statsmodels-0.14.6 strsimpy-0.2.1 typing-inspection-0.4.2 werkzeug-3.1.8 xarray-2026.4.0 xlrd-2.0.2 zipp-4.1.0

# %%
import dtale

# %%
dtale.show(df, open_browser=True)

# %%
df.to_csv("clean_data.csv")

# %%
pd.read_csv("clean_data.csv").isnull().sum()
# Out:
# Unnamed: 0                 0
# age                        0
# gender                     0
# occupation                 0
# sleep_hours                0
# sleep_quality              0
# social_media_hours         0
# academic_work_pressure     0
# physical_activity_days     0
# stress_level               0
# anxiety_score              0
# depression_score           0
# work_life_balance          0
# mood_score                 0
# concentration_level        0
# social_support             0
# mental_health_condition    0
# severity                   0
# treatment                  0
# dtype: int64
